# %%
import pandas as pd

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
s1=pd.Series([1,4,7,2,5])

# %%
s1
# Out:
# 0    1
# 1    4
# 2    7
# 3    2
# 4    5
# dtype: int64

# %%
months=pd.Series(["Jan","Feb","Mar","Apr","May"])

# %%
months
# Out:
# 0    Jan
# 1    Feb
# 2    Mar
# 3    Apr
# 4    May
# dtype: object

# %%
months.index=[1,2,3,4,5]

# %%
months
# Out:
# 1    Jan
# 2    Feb
# 3    Mar
# 4    Apr
# 5    May
# dtype: object

# %%
days=pd.Series([31,28,31,30,31],index=["Jan","Feb","Mar","Apr","May"])

# %%
days
# Out:
# Jan    31
# Feb    28
# Mar    31
# Apr    30
# May    31
# dtype: int64

# %%
days.index
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May'], dtype='object')

# %%
days.values
# Out:
# array([31, 28, 31, 30, 31], dtype=int64)

# %%
days.sum
# Out:
# <bound method Series.sum of Jan    31
# Feb    28
# Mar    31
# Apr    30
# May    31
# dtype: int64>

# %%
days.sum()
# Out:
# 151

# %%
days.mean()
# Out:
# 30.2

# %%
days.mode()
# Out:
# 0    31
# dtype: int64

# %%
days.std()
# Out:
# 1.30384048104053

# %%
days.value_counts()
# Out:
# 31    3
# 28    1
# 30    1
# Name: count, dtype: int64

# %%
days=pd.Series(["Jan","Feb","Mar","Apr","May"],index=[31,28,31,30,31])

# %%
days
# Out:
# 31    Jan
# 28    Feb
# 31    Mar
# 30    Apr
# 31    May
# dtype: object

# %%
days=pd.Series([31,30,31,30,31],index=["Dec","Nov","Oct","Sep","Aug"])

# %%
days
# Out:
# Dec    31
# Nov    30
# Oct    31
# Sep    30
# Aug    31
# dtype: int64

# %%
d1=days.reset_index(drop=True)

# %%
d1
# Out:
# 0    31
# 1    30
# 2    31
# 3    30
# 4    31
# dtype: int64

# %%
d2=days.reset_index(drop=True)

# %%
d2
# Out:
# 0    31
# 1    30
# 2    31
# 3    30
# 4    31
# dtype: int64

# %%
d1+d2
# Out:
# 0    62
# 1    60
# 2    62
# 3    60
# 4    62
# dtype: int64

# %%
days.index
# Out:
# Index(['Dec', 'Nov', 'Oct', 'Sep', 'Aug'], dtype='object')

# %%
days.index.tolist()
# Out:
# ['Dec', 'Nov', 'Oct', 'Sep', 'Aug']

# %% [raw]
#  #Data Frame:- Data stucture To create a Data Frame with the help of Pandas

# %%
dict={"Name":["Sachine","Dhoni","Virat","Rohit"],"Jersey":[10,7,18,45]}

# %%
dict
# Out:
# {'Name': ['Sachine', 'Dhoni', 'Virat', 'Rohit'], 'Jersey': [10, 7, 18, 45]}

# %%
Players=pd.DataFrame(dict)

# %%
Players
# Out:
#       Name  Jersey
# 0  Sachine      10
# 1    Dhoni       7
# 2    Virat      18
# 3    Rohit      45

# %%
list=[
    {"Name":"Sachine","Jersey":10},
    {"Name":"Dhoni","Jersey":7},
    {"Name":"Virat","Jersey":18},
    {"Name":"Rohit","Jersey":45},
]

# %%
list
# Out:
# [{'Name': 'Sachine', 'Jersey': 10},
#  {'Name': 'Dhoni', 'Jersey': 7},
#  {'Name': 'Virat', 'Jersey': 18},
#  {'Name': 'Rohit', 'Jersey': 45}]

# %%
player=pd.DataFrame(list)

# %%
player
# Out:
#       Name  Jersey
# 0  Sachine      10
# 1    Dhoni       7
# 2    Virat      18
# 3    Rohit      45

# %% [markdown]
# # To create a Data Fream with the help of np

# %%
import numpy as np

# %%
df1=pd.DataFrame(np.arange(1,25).reshape(6,4),
                columns=["Col1","Col2","Col3","Col4"])

# %%
df1
# Out:
#    Col1  Col2  Col3  Col4
# 0     1     2     3     4
# 1     5     6     7     8
# 2     9    10    11    12
# 3    13    14    15    16
# 4    17    18    19    20
# 5    21    22    23    24

# %%
data=np.random.randint(35,99,100)

# %%
data.reshape(5,20)
# Out:
# array([[64, 66, 37, 51, 91, 71, 66, 79, 65, 52, 98, 91, 94, 84, 81, 80,
#         47, 79, 67, 91],
#        [97, 52, 86, 58, 98, 41, 49, 77, 44, 50, 72, 47, 39, 90, 35, 68,
#         50, 77, 94, 63],
#        [42, 57, 87, 96, 40, 48, 52, 52, 60, 82, 65, 91, 64, 68, 85, 96,
#         92, 39, 68, 39],
#        [35, 90, 56, 77, 86, 64, 54, 74, 64, 47, 53, 38, 63, 60, 91, 62,
#         87, 90, 73, 60],
#        [65, 90, 94, 38, 82, 70, 51, 36, 91, 89, 38, 52, 77, 56, 45, 72,
#         59, 46, 41, 87]])

# %%
df2=pd.read_excel(r"C:\Users\yasht\Downloads\global_superstore.xlsx")

# %%
df2
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df2.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
df2.head(3)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  ...  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City  ...
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong  ...
# 2     CR-127307   Craig Reiter   Consumer          NaN       Brisbane  ...
#
#     Product ID    Category Sub-Category  \
# 0  TEC-PH-5816  Technology       Phones
# 1  FUR-CH-5379   Furniture       Chairs
# 2  TEC-PH-5356  Technology       Phones
#
#                                 Product Name     Sales Quantity Discount  \
# 0                           Samsung Convoy 3   221.980        2      0.0
# ...

# %%
df3=pd.read_csv(r"C:\Users\yasht\Downloads\data.csv")

# %%
df3
# Out:
#     Sub-Category  Market          Region                 Order ID  \
# 0        Binders  Europe  Western Europe  ES-2012-AR1040548-41067
# 1        Binders  Europe  Western Europe  ES-2012-AR1040548-41067
# 2        Binders  Europe  Western Europe  ES-2012-AR1040548-41067
# 3        Binders  Europe  Western Europe  ES-2012-AR1082548-41181
# 4        Binders  Europe  Western Europe  ES-2012-BM1114048-41222
# ..           ...     ...             ...                      ...
# 250      Binders  Europe  Western Europe  IT-2015-GT1475548-42266
# 251      Binders  Europe  Western Europe  IT-2015-GT1475548-42266
# 252      Binders  Europe  Western Europe  IT-2015-JW1522048-42256
# 253      Binders  Europe  Western Europe  IT-2015-MH1744048-42325
# 254      Binders  Europe  Western Europe  IT-2015-NG1835548-42309
#
#           Ship Mode Customer ID     Customer Name    Segment         City  \
# 0    Standard Class  AR-1040548  Allen Rosenblatt  Corporate       Berlin
# ...

# %%
df3.describe()
# Out:
#        Sub-Category  Market          Region                 Order ID  \
# count           255     255             255                      255
# unique            1       1               1                      221
# top         Binders  Europe  Western Europe  ES-2012-AR1040548-41067
# freq            255     255             255                        3
#
#              Ship Mode Customer ID Customer Name   Segment    City  \
# count              255         255           255       255     255
# unique               4         193           193         3      85
# top     Standard Class  GG-1465048  Greg Guthrie  Consumer  Berlin
# freq               155           5             5       133      28
#
#                          State  Country   Product ID         Category  \
# count                      255      255          255              255
# unique                      15        1          104                1
# ...

# %%
df1.describe()
# Out:
#             Col1       Col2       Col3       Col4
# count   6.000000   6.000000   6.000000   6.000000
# mean   11.000000  12.000000  13.000000  14.000000
# std     7.483315   7.483315   7.483315   7.483315
# min     1.000000   2.000000   3.000000   4.000000
# 25%     6.000000   7.000000   8.000000   9.000000
# 50%    11.000000  12.000000  13.000000  14.000000
# 75%    16.000000  17.000000  18.000000  19.000000
# max    21.000000  22.000000  23.000000  24.000000

# %%
df2.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2014-05-11 21:26:49.155780608
# min        1.00000            2012-01-01 00:00:00
# 25%    12823.25000            2013-06-19 00:00:00
# 50%    25645.50000            2014-07-08 00:00:00
# 75%    38467.75000            2015-05-22 00:00:00
# max    51290.00000            2015-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2014-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2012-01-03 00:00:00   1040.000000      0.444000
# 25%              2013-06-23 00:00:00  23223.000000     30.758625
# 50%              2014-07-12 00:00:00  56430.500000     85.053000
# 75%              2015-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
df2[["Sales","Quantity"]].head()
# Out:
#       Sales  Quantity
# 0   221.980         2
# 1  3709.395         9
# 2  5175.171         9
# 3  2892.510         5
# 4  2832.960         8

# %%
df2[["Sales","Quantity"]].head(3)
# Out:
#       Sales  Quantity
# 0   221.980         2
# 1  3709.395         9
# 2  5175.171         9

# %%
df2[["Sales","Quantity"]].tail(3)
# Out:
#        Sales  Quantity
# 51287   8.56         2
# 51288  13.44         2
# 51289  61.38         3

# %%
df2["Region"].head()
# Out:
# 0        Central US
# 1           Oceania
# 2           Oceania
# 3    Western Europe
# 4    Western Africa
# Name: Region, dtype: object

# %%
df2.loc[100:200:10]
# Out:
#      Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 100   46257    CG-2014-HM498033-41846 2014-07-26 2014-08-01  Standard Class
# 110   32648  CA-2014-AS10045140-41727 2014-03-29 2014-04-01     First Class
# 120   21668    IN-2014-CM121157-41913 2014-10-01 2014-10-02     First Class
# 130   23880   IN-2014-SV2081558-41968 2014-11-25 2014-11-27     First Class
# 140    2283   MX-2013-PV1898518-41614 2013-12-06 2013-12-08     First Class
# 150   15376   IT-2012-GM1468091-41215 2012-11-02 2012-11-05     First Class
# 160   22058   IN-2014-SO2033527-41914 2014-10-02 2014-10-04     First Class
# 170   21639    ID-2014-RL196157-41641 2014-01-02 2014-01-03     First Class
# 180   51130   UP-2015-DJ3510137-42202 2015-07-17 2015-07-19    Second Class
# 190   24859   IN-2015-JF1519021-42341 2015-12-03 2015-12-07  Standard Class
# 200   24361   IN-2014-NM1844527-41800 2014-06-10 2014-06-10        Same Day
#
# ...

# %%
df2["City"].unique()
# Out:
# array(['Oklahoma City', 'Wollongong', 'Brisbane', ..., 'San Mateo',
#        'Portage', 'Victoria Falls'], dtype=object)

# %%
df2.sort_values("Sales")
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51260   35398  US-2015-ZC21910140-42175 2015-06-20 2015-06-24  Standard Class
# 45391   40589  CA-2015-RS19765140-42066 2015-03-03 2015-03-03        Same Day
# 33493   39955  CA-2014-KB16600140-41812 2014-06-22 2014-06-26  Standard Class
# 26588   36008  CA-2012-JO15280140-40998 2012-03-30 2012-03-30        Same Day
# 24977   33403  US-2012-HG14965140-41177 2012-09-25 2012-09-25        Same Day
# ...       ...                       ...        ...        ...             ...
# 25238   35487  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# 49940   33920  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
# 44248   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 49003   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 47114   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
#
# ...

# %%
df2.sort_values("Sales",ascending=False)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 47114   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 49003   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 44248   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 49940   33920  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
# 25238   35487  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# ...       ...                       ...        ...        ...             ...
# 24977   33403  US-2012-HG14965140-41177 2012-09-25 2012-09-25        Same Day
# 26588   36008  CA-2012-JO15280140-40998 2012-03-30 2012-03-30        Same Day
# 33493   39955  CA-2014-KB16600140-41812 2014-06-22 2014-06-26  Standard Class
# 45391   40589  CA-2015-RS19765140-42066 2015-03-03 2015-03-03        Same Day
# 51260   35398  US-2015-ZC21910140-42175 2015-06-20 2015-06-24  Standard Class
#
# ...

# %%
df2[(df2["Category"]=="Technology")&(df2["Sub-Category"]=="Copiers")]["Sales"].sum()
# Out:
# 1509436.2732799998

# %%
df2[(df2["Category"]=="Technology")&(df2["Sub-Category"]=="Copiers")]["Sales"].mean()
# Out:
# 679.0086699415205

# %% [markdown]
# #only those record who is sales is greater than 3000?

# %%
df2[df2["Sales"]>=1000]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# ...       ...                       ...        ...        ...             ...
# 51152   32050  CA-2014-YC21895140-41737 2014-04-08 2014-04-10     First Class
# 51191   32496  CA-2014-ZC21910140-41738 2014-04-09 2014-04-13  Standard Class
# 51192   32107  CA-2012-ZC21910140-41194 2012-10-12 2012-10-14     First Class
# 51193   36485  CA-2013-ZC21910140-41530 2013-09-13 2013-09-18  Standard Class
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14  Standard Class
#
# ...

# %%
df2[df2["Sales"]>=1000].sort_values("Sales").head(3)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51129   37507  CA-2015-YS21880140-42235 2015-08-19 2015-08-26  Standard Class
# 51128   32910  CA-2015-YS21880140-42360 2015-12-22 2015-12-26  Standard Class
# 2017     4993   MX-2012-RA1991518-41226 2012-11-13 2012-11-14     First Class
#
#         Customer ID      Customer Name    Segment  Postal Code       City  \
# 51129  YS-218801404      Yana Sorensen  Corporate      98103.0    Seattle
# 51128  YS-218801404      Yana Sorensen  Corporate      94601.0    Oakland
# 2017     RA-1991518  Russell Applegate   Consumer          NaN  Itamaraju
#
#        ...   Product ID         Category Sub-Category  \
# 51129  ...  OFF-ST-5076  Office Supplies      Storage
# 51128  ...  OFF-ST-5076  Office Supplies      Storage
# 2017   ...  OFF-AP-4502  Office Supplies   Appliances
#
#                            Product Name    Sales Quantity Discount    Profit  \
# ...

# %%
df2.query("Sales==1003")
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Postal Code, City, State, Country, Region, Market, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df2.query("Category=='Furniture'and Sales>=1003")
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 6       30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7       31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 11      28879    ID-2013-AJ107801-41383 2013-04-19 2013-04-22     First Class
# 13       4132   MX-2013-VF2171518-41591 2013-11-13 2013-11-13        Same Day
# ...       ...                       ...        ...        ...             ...
# 50502   40862  CA-2012-TG21640140-40998 2012-03-30 2012-03-30        Same Day
# 50772   40290  CA-2015-VP21760140-42294 2015-10-17 2015-10-22  Standard Class
# 50803   40725  CA-2012-VW21775140-41039 2012-05-10 2012-05-15  Standard Class
# 51192   32107  CA-2012-ZC21910140-41194 2012-10-12 2012-10-14     First Class
# 51193   36485  CA-2013-ZC21910140-41530 2013-09-13 2013-09-18  Standard Class
#
# ...

# %%
import pandas as pd

# %%
ss= pd.read_excel(r"C:\Users\yasht\Downloads\global_superstore.xlsx")

# %%
ss.groupby("Category")[["Sales","Profit","Quantity"]].sum()
# Out:
#                         Sales        Profit  Quantity
# Category
# Furniture        4.110452e+06  285082.73020     34892
# Office Supplies  3.787493e+06  518595.82790    108244
# Technology       4.744557e+06  663778.73318     35176

# %%
ss.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
ss["Region"].value_counts()
# Out:
# Region
# Western Europe       5883
# Central America      5616
# Oceania              3487
# Western US           3203
# Southeastern Asia    3129
# South America        2988
# Eastern US           2848
# Southern Asia        2655
# Western Asia         2440
# Eastern Asia         2374
# Central US           2323
# Northern Europe      2204
# Southern Europe      2113
# Caribbean            1690
# Southern US          1620
# Eastern Europe       1529
# Western Africa       1460
# North Africa         1278
# Eastern Africa        728
# Central Africa        643
# Southern Africa       478
# Canada                384
# Central Asia          217
# Name: count, dtype: int64

# %%
ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
pd.crosstab(ss["Region"],ss["Segment"])
# Out:
# Segment            Consumer  Corporate  Home Office
# Region
# Canada                  202        110           72
# Caribbean               828        507          355
# Central Africa          356        169          118
# Central America        2891       1717         1008
# Central Asia            125         48           44
# Central US             1212        673          438
# Eastern Africa          347        206          175
# Eastern Asia           1174        729          471
# Eastern Europe          790        450          289
# Eastern US             1469        877          502
# North Africa            690        345          243
# Northern Europe        1118        701          385
# Oceania                1837       1053          597
# South America          1602        829          557
# Southeastern Asia      1650        909          570
# Southern Africa         223        156           99
# Southern Asia          1358        805          492
# ...

# %%
ss.isna().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
ss.duplicated().sum()
# Out:
# 0
